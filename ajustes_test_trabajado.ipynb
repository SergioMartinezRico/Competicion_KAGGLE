# %% [markdown]
# # Creación de Modelos de ML

# %% [markdown]
# ## Importaciones

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error,mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Carga del CSV de test trabajado

# %%
df = pd.read_csv("data/test_trabajado.csv" )
df.head()
# Out:
#      id  laptop_ID Company         Product   TypeName  Inches  \
# 0   181       1098      HP    Spectre x360  Ultrabook    13.3
# 1   708        330    Acer        Aspire 5   Notebook    15.6
# 2   862       1260    Acer  Aspire ES1-572   Notebook    15.6
# 3  1064       1137      HP  EliteBook 1040   Notebook    14.0
# 4   702       1015      HP          ENVY -   Notebook    13.3
#
#                   ScreenResolution                          Cpu   Ram  \
# 0  IPS Panel 4K Ultra HD 3840x2160   Intel Core i7 7500U 2.7GHz  16.0
# 1                         1366x768  AMD A12-Series 9720P 2.7GHz   8.0
# 2                         1366x768   Intel Core i3 6006U 2.0GHz   4.0
# 3                Full HD 1920x1080   Intel Core i5 6200U 2.3GHz   8.0
# 4      IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   8.0
#
#       Memory  ... Touchscreen FullHD  QuadHD  UltraHD_4K  Retina  CPU_Marca  \
# 0  512GB SSD  ...           0      0       0           1       0      Intel
# 1  256GB SSD  ...           0      0       0           0       0        AMD
# 2  500GB HDD  ...           0      0       0           0       0      Intel
# 3  256GB SSD  ...           0      1       0           0       0      Intel
# 4  256GB SSD  ...           0      1       0           0       0      Intel
#
#    CPU_Serie CPU_GHz  GPU_Marca     GPU_Tipo
# 0         i7     2.7      Intel  HD Graphics
# 1          M     2.7        AMD       Radeon
# 2         i3     2.0      Intel  HD Graphics
# 3         i5     2.3      Intel  HD Graphics
# 4         i5     2.5      Intel  HD Graphics
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Escalado

# %% [markdown]
# Escalar las columnas numericas con StandardScaler para trabajar con valores escalados

# %%
df.columns
# Out:
# Index(['id', 'laptop_ID', 'Company', 'Product', 'TypeName', 'Inches',
#        'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight',
#        'SSD_GB', 'HDD_GB', 'Hybrid_GB', 'Flash_GB', 'ScreenResolution_clean',
#        'Width_px', 'Height_px', 'PPI', 'IPS', 'Touchscreen', 'FullHD',
#        'QuadHD', 'UltraHD_4K', 'Retina', 'CPU_Marca', 'CPU_Serie', 'CPU_GHz',
#        'GPU_Marca', 'GPU_Tipo'],
#       dtype='object')

# %%
lista_columnas_escala = ["Ram", "Weight", "SSD_GB", "HDD_GB", "Hybrid_GB", "Flash_GB", "PPI", "CPU_GHz"]

# %%
scaler = StandardScaler()

# %%
df[lista_columnas_escala] = scaler.fit_transform(df[lista_columnas_escala])

# %%
df[lista_columnas_escala].head()
# Out:
#         Ram    Weight    SSD_GB    HDD_GB  Hybrid_GB  Flash_GB       PPI  \
# 0  1.311382 -1.090284  1.651244 -0.817083  -0.084528 -0.168265  4.276645
# 1 -0.152573  0.210807  0.327880 -0.817083  -0.084528 -0.168265 -1.099063
# 2 -0.884551  0.499939 -0.995485  0.085932  -0.084528 -0.168265 -1.099063
# 3 -0.152573 -0.902349  0.327880 -0.817083  -0.084528 -0.168265  0.226079
# 4 -0.152573 -1.032458  0.327880 -0.817083  -0.084528 -0.168265  0.418963
#
#     CPU_GHz
# 0  0.768848
# 1  0.768848
# 2 -0.663063
# 3 -0.049387
# 4  0.359730

# %% [markdown]
# Una vez escalados los numericos hay que ver como afectan los no numericos

# %%
df["Company"].value_counts()
# Out:
# Company
# Dell         90
# Lenovo       89
# HP           85
# Asus         50
# Acer         28
# MSI          20
# Toshiba      11
# Apple         4
# Samsung       3
# Microsoft     3
# LG            2
# Razer         1
# Vero          1
# Chuwi         1
# Huawei        1
# Xiaomi        1
# Google        1
# Name: count, dtype: int64

# %% [markdown]
# Agrupar las marcas que menos frecuencia tienen en un unico grupo

# %%
marcas_frecuentes = ["Lenovo", "Dell", "HP", "Asus", "Acer", "Toshiba", "MSI", "Apple"]

df["Company_clean"] = df["Company"].apply(lambda x: x if x in marcas_frecuentes else "Otros")

# %%
df["TypeName"].value_counts()
# Out:
# TypeName
# Notebook              205
# Gaming                 67
# Ultrabook              61
# 2 in 1 Convertible     36
# Workstation            11
# Netbook                11
# Name: count, dtype: int64

# %%
tipos_frecuentes = ["Notebook", "Gaming", "Ultrabook", "2 in 1 Convertible"]
df["TypeName_clean"] = df["TypeName"].apply(lambda x: x if x in tipos_frecuentes else "Otros")

# %% [markdown]
# Para las CPU trabajamos con las series. Si hace falta mas trabajaremos con las frecuencias
# Investigando y comparando series de AMD e Intel, quedaria mas o menos asi.

# %%
df["CPU_Serie"].unique()
# Out:
# array(['i7', 'M', 'i3', 'i5', 'Atom', 'Celeron', 'Pentium', 'Other'],
#       dtype=object)

# %%
df["CPU_Serie"].count()
# Out:
# np.int64(391)

# %%
cpu_potencia = {
    "Atom": 0,
    "Celeron": 1,
    "M": 2,
    "Pentium": 3,
    "i3": 4,
    "i5": 5,
    "i7": 6,
    "Other": 3
}

# %%
df["CPU_Potencia"] = df["CPU_Serie"].map(cpu_potencia)

# %%
df["CPU_Potencia"].count()
# Out:
# np.int64(391)

# %% [markdown]
# Ahora las GPU

# %%
df["GPU_Tipo"].value_counts()
# Out:
# GPU_Tipo
# HD Graphics    197
# GeForce        121
# Radeon          56
# Quadro          11
# Iris Plus        2
# FirePro          2
# Iris             1
# Other            1
# Name: count, dtype: int64

# %%
gpu_potencia = {
    "HD Graphics": 1,
    "Iris": 2,
    "Iris Plus": 2,
    "Radeon": 3,
    "GeForce": 4,
    "Quadro": 5,
    "FirePro": 5,
    "Other AMD": 3,
    "Other Nvidia": 4,
    "Other Intel": 1,
    "Other": 3
}

# %%
df["GPU_Potencia"] = df["GPU_Tipo"].map(gpu_potencia)

# %% [markdown]
# Ahora volvemos a escalar todo

# %%
columnas_a_escalar = [
    "Ram", "Weight", "SSD_GB", "HDD_GB", "Hybrid_GB", "Flash_GB",
    "PPI", "CPU_GHz", "CPU_Potencia", "GPU_Potencia"
]

# %%
df[columnas_a_escalar] = scaler.fit_transform(df[columnas_a_escalar])

# %%
df[columnas_a_escalar].head()
# Out:
#         Ram    Weight    SSD_GB    HDD_GB  Hybrid_GB  Flash_GB       PPI  \
# 0  1.311382 -1.090284  1.651244 -0.817083  -0.084528 -0.168265  4.276645
# 1 -0.152573  0.210807  0.327880 -0.817083  -0.084528 -0.168265 -1.099063
# 2 -0.884551  0.499939 -0.995485  0.085932  -0.084528 -0.168265 -1.099063
# 3 -0.152573 -0.902349  0.327880 -0.817083  -0.084528 -0.168265  0.226079
# 4 -0.152573 -1.032458  0.327880 -0.817083  -0.084528 -0.168265  0.418963
#
#     CPU_GHz  CPU_Potencia  GPU_Potencia
# 0  0.768848      0.760480     -0.948754
# 1  0.768848     -1.853567      0.445843
# 2 -0.663063     -0.546543     -0.948754
# 3 -0.049387      0.106969     -0.948754
# 4  0.359730      0.106969     -0.948754

# %% [markdown]
# Ahora One Hot Encoding para marca (Company) y tipo de portatil (TypeName)

# %%
df_encoded = pd.get_dummies(df, columns=["Company", "TypeName"], drop_first=True)

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 55 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      391 non-null    int64
#  1   laptop_ID               391 non-null    int64
#  2   Product                 391 non-null    object
#  3   Inches                  391 non-null    float64
#  4   ScreenResolution        391 non-null    object
#  5   Cpu                     391 non-null    object
#  6   Ram                     391 non-null    float64
#  7   Memory                  391 non-null    object
#  8   Gpu                     391 non-null    object
#  9   OpSys                   391 non-null    object
#  10  Weight                  391 non-null    float64
#  11  SSD_GB                  391 non-null    float64
#  12  HDD_GB                  391 non-null    float64
#  13  Hybrid_GB               391 non-null    float64
#  14  Flash_GB                391 non-null    float64
#  15  ScreenResolution_clean  391 non-null    object
#  16  Width_px                391 non-null    int64
#  17  Height_px               391 non-null    int64
#  18  PPI                     391 non-null    float64
#  19  IPS                     391 non-null    int64
#  20  Touchscreen             391 non-null    int64
#  21  FullHD                  391 non-null    int64
#  22  QuadHD                  391 non-null    int64
#  23  UltraHD_4K              391 non-null    int64
#  24  Retina                  391 non-null    int64
#  25  CPU_Marca               391 non-null    object
#  26  CPU_Serie               391 non-null    object
#  27  CPU_GHz                 391 non-null    float64
#  28  GPU_Marca               391 non-null    object
#  29  GPU_Tipo                391 non-null    object
#  30  Company_clean           391 non-null    object
#  31  TypeName_clean          391 non-null    object
#  32  CPU_Potencia            391 non-null    float64
#  33  GPU_Potencia            391 non-null    float64
#  34  Company_Apple           391 non-null    bool
#  35  Company_Asus            391 non-null    bool
#  36  Company_Chuwi           391 non-null    bool
#  37  Company_Dell            391 non-null    bool
#  38  Company_Google          391 non-null    bool
#  39  Company_HP              391 non-null    bool
#  40  Company_Huawei          391 non-null    bool
#  41  Company_LG              391 non-null    bool
#  42  Company_Lenovo          391 non-null    bool
#  43  Company_MSI             391 non-null    bool
#  44  Company_Microsoft       391 non-null    bool
#  45  Company_Razer           391 non-null    bool
#  46  Company_Samsung         391 non-null    bool
#  47  Company_Toshiba         391 non-null    bool
#  48  Company_Vero            391 non-null    bool
#  49  Company_Xiaomi          391 non-null    bool
#  50  TypeName_Gaming         391 non-null    bool
#  51  TypeName_Netbook        391 non-null    bool
#  52  TypeName_Notebook       391 non-null    bool
#  53  TypeName_Ultrabook      391 non-null    bool
#  54  TypeName_Workstation    391 non-null    bool
# dtypes: bool(21), float64(11), int64(10), object(13)
# memory usage: 112.0+ KB

# %%
# Columnas numéricas escaladas
num_cols = ["Ram","Weight","SSD_GB","HDD_GB","Hybrid_GB","Flash_GB","PPI","CPU_GHz","CPU_Potencia","GPU_Potencia"]

# Columnas binarias (pantalla)
binary_cols = ["IPS","Touchscreen","FullHD","QuadHD","UltraHD_4K","Retina"]

# Columnas one-hot
company_cols = [col for col in df_encoded.columns if col.startswith("Company_")]
typename_cols = [col for col in df_encoded.columns if col.startswith("TypeName_")]
#Columna target


# Todas las columnas finales
model_cols = num_cols + binary_cols + company_cols + typename_cols

# DataFrame final
df_final = df_encoded[model_cols]

df_final.head()
# Out:
#         Ram    Weight    SSD_GB    HDD_GB  Hybrid_GB  Flash_GB       PPI  \
# 0  1.311382 -1.090284  1.651244 -0.817083  -0.084528 -0.168265  4.276645
# 1 -0.152573  0.210807  0.327880 -0.817083  -0.084528 -0.168265 -1.099063
# 2 -0.884551  0.499939 -0.995485  0.085932  -0.084528 -0.168265 -1.099063
# 3 -0.152573 -0.902349  0.327880 -0.817083  -0.084528 -0.168265  0.226079
# 4 -0.152573 -1.032458  0.327880 -0.817083  -0.084528 -0.168265  0.418963
#
#     CPU_GHz  CPU_Potencia  GPU_Potencia  ...  Company_Samsung  \
# 0  0.768848      0.760480     -0.948754  ...            False
# 1  0.768848     -1.853567      0.445843  ...            False
# 2 -0.663063     -0.546543     -0.948754  ...            False
# 3 -0.049387      0.106969     -0.948754  ...            False
# 4  0.359730      0.106969     -0.948754  ...            False
#
#    Company_Toshiba  Company_Vero  Company_Xiaomi  TypeName_clean  \
# 0            False         False           False       Ultrabook
# 1            False         False           False        Notebook
# 2            False         False           False        Notebook
# 3            False         False           False        Notebook
# 4            False         False           False        Notebook
#
#    TypeName_Gaming TypeName_Netbook  TypeName_Notebook  TypeName_Ultrabook  \
# 0            False            False              False                True
# 1            False            False               True               False
# 2            False            False               True               False
# 3            False            False               True               False
# 4            False            False               True               False
#
#    TypeName_Workstation
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
#
# [5 rows x 39 columns]

# %% [markdown]
# Elimino las columnas con baja relacion como Flash_GB, Quad... y CPU_GHz por tener mucha correlacion con CPU_Potencia y estar las 2 bien relacionadas con Price

# %%
columnas_a_quitar = ["HDD_GB", "Hybrid_GB", "Flash_GB", "Weight", "FullHD", "QuadHD", "Retina", "CPU_GHz","Company_clean","TypeName_clean"]
df_simplificado = df_final.drop(columns=columnas_a_quitar)
df_simplificado.head()
# Out:
#         Ram    SSD_GB       PPI  CPU_Potencia  GPU_Potencia  IPS  Touchscreen  \
# 0  1.311382  1.651244  4.276645      0.760480     -0.948754    1            0
# 1 -0.152573  0.327880 -1.099063     -1.853567      0.445843    0            0
# 2 -0.884551 -0.995485 -1.099063     -0.546543     -0.948754    0            0
# 3 -0.152573  0.327880  0.226079      0.106969     -0.948754    0            0
# 4 -0.152573  0.327880  0.418963      0.106969     -0.948754    1            0
#
#    UltraHD_4K  Company_Apple  Company_Asus  ...  Company_Razer  \
# 0           1          False         False  ...          False
# 1           0          False         False  ...          False
# 2           0          False         False  ...          False
# 3           0          False         False  ...          False
# 4           0          False         False  ...          False
#
#    Company_Samsung  Company_Toshiba  Company_Vero  Company_Xiaomi  \
# 0            False            False         False           False
# 1            False            False         False           False
# 2            False            False         False           False
# 3            False            False         False           False
# 4            False            False         False           False
#
#    TypeName_Gaming  TypeName_Netbook  TypeName_Notebook  TypeName_Ultrabook  \
# 0            False             False              False                True
# 1            False             False               True               False
# 2            False             False               True               False
# 3            False             False               True               False
# 4            False             False               True               False
#
#    TypeName_Workstation
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
#
# [5 rows x 29 columns]

# %%
df_simplificado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Ram                   391 non-null    float64
#  1   SSD_GB                391 non-null    float64
#  2   PPI                   391 non-null    float64
#  3   CPU_Potencia          391 non-null    float64
#  4   GPU_Potencia          391 non-null    float64
#  5   IPS                   391 non-null    int64
#  6   Touchscreen           391 non-null    int64
#  7   UltraHD_4K            391 non-null    int64
#  8   Company_Apple         391 non-null    bool
#  9   Company_Asus          391 non-null    bool
#  10  Company_Chuwi         391 non-null    bool
#  11  Company_Dell          391 non-null    bool
#  12  Company_Google        391 non-null    bool
#  13  Company_HP            391 non-null    bool
#  14  Company_Huawei        391 non-null    bool
#  15  Company_LG            391 non-null    bool
#  16  Company_Lenovo        391 non-null    bool
#  17  Company_MSI           391 non-null    bool
#  18  Company_Microsoft     391 non-null    bool
#  19  Company_Razer         391 non-null    bool
#  20  Company_Samsung       391 non-null    bool
#  21  Company_Toshiba       391 non-null    bool
#  22  Company_Vero          391 non-null    bool
#  23  Company_Xiaomi        391 non-null    bool
#  24  TypeName_Gaming       391 non-null    bool
#  25  TypeName_Netbook      391 non-null    bool
#  26  TypeName_Notebook     391 non-null    bool
#  27  TypeName_Ultrabook    391 non-null    bool
#  28  TypeName_Workstation  391 non-null    bool
# dtypes: bool(21), float64(5), int64(3)
# memory usage: 32.6 KB

# %%
df_simplificado.to_csv("data/datos_a_predecir.csv", index = False)
